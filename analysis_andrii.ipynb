# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %matplotlib inline

# %%
df = pd.read_csv("immoweb_data_cleaned_combined.csv")
df.head()
# Out:
#       Price Locality Type_of_Property Subtype_of_Property  \
# 0  685000.0     1180        APARTMENT           PENTHOUSE
# 1  289000.0     8680        APARTMENT           APARTMENT
# 2  775000.0     2980            HOUSE               VILLA
# 3  259000.0     5030            HOUSE               HOUSE
# 4  230000.0     8690            HOUSE               HOUSE
#
#   State_of_the_Building  Number_of_Rooms  Fully_Equipped_Kitchen  \
# 0        JUST_RENOVATED              2.0                   False
# 1        JUST_RENOVATED              3.0                   False
# 2         TO_BE_DONE_UP              4.0                   False
# 3                  GOOD              3.0                   False
# 4           TO_RENOVATE              4.0                   False
#
#           Province  Municipality    Price_Group         Price_Group_Per_Region
# 0          Brussel         Ukkel  550000-750000          Brussel_550000-750000
# 1  West-Vlaanderen         Zande  200000-350000  West-Vlaanderen_200000-350000
# 2        Antwerpen       Zoersel  750000-950000        Antwerpen_750000-950000
# 3            Namen    Sauvenière  200000-350000            Namen_200000-350000
# 4  West-Vlaanderen  Sint-Rijkers  200000-350000  West-Vlaanderen_200000-350000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16797 entries, 0 to 16796
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Price                   16797 non-null  float64
#  1   Locality                16797 non-null  object
#  2   Type_of_Property        16797 non-null  object
#  3   Subtype_of_Property     16797 non-null  object
#  4   State_of_the_Building   16797 non-null  object
#  5   Number_of_Rooms         16797 non-null  float64
#  6   Fully_Equipped_Kitchen  16797 non-null  bool
#  7   Province                16797 non-null  object
#  8   Municipality            16797 non-null  object
#  9   Price_Group             16797 non-null  object
#  10  Price_Group_Per_Region  16797 non-null  object
# dtypes: bool(1), float64(2), object(8)
# memory usage: 1.3+ MB

# %%
df.isna().sum()
# Out:
# Price                     0
# Locality                  0
# Type_of_Property          0
# Subtype_of_Property       0
# State_of_the_Building     0
# Number_of_Rooms           0
# Fully_Equipped_Kitchen    0
# Province                  0
# Municipality              0
# Price_Group               0
# Price_Group_Per_Region    0
# dtype: int64

# %%
df.shape
# Out:
# (16797, 11)

# %%
df.describe()
# Out:
#                Price  Number_of_Rooms
# count   16797.000000     16797.000000
# mean   346378.958802         2.564089
# std    161067.380347         0.908084
# min      5000.000000         1.000000
# 25%    230000.000000         2.000000
# 50%    315000.000000         3.000000
# 75%    425000.000000         3.000000
# max    880000.000000         4.000000

# %%
df.describe(include='object')
# Out:
#        Locality Type_of_Property Subtype_of_Property State_of_the_Building  \
# count     16797            16797               16797                 16797
# unique      914                2                  22                     6
# top        9000            HOUSE               HOUSE                  GOOD
# freq        427             8580                7045                  7991
#
#                Province Municipality    Price_Group  \
# count             16797        16797          16797
# unique               12          879              6
# top     Oost-Vlaanderen    Antwerpen  200000-350000
# freq               3184          557           7111
#
#                Price_Group_Per_Region
# count                           16797
# unique                             71
# top     Oost-Vlaanderen_200000-350000
# freq                             1383

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16797 entries, 0 to 16796
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Price                   16797 non-null  float64
#  1   Locality                16797 non-null  object
#  2   Type_of_Property        16797 non-null  object
#  3   Subtype_of_Property     16797 non-null  object
#  4   State_of_the_Building   16797 non-null  object
#  5   Number_of_Rooms         16797 non-null  float64
#  6   Fully_Equipped_Kitchen  16797 non-null  bool
#  7   Province                16797 non-null  object
#  8   Municipality            16797 non-null  object
#  9   Price_Group             16797 non-null  object
#  10  Price_Group_Per_Region  16797 non-null  object
# dtypes: bool(1), float64(2), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# ## **Data Intepretation**
#
# - Which variable is the target ?
# Price
#
# - How many rows and columns ?
# 16797 rows & 11 columns
#
# - How many qualitative and quantitative variable is there ?
# # ????????????????????????There are 3 quantitative variables (or Numerical variables):
# # ????????????????????????There are 2 continuous quantitative variables (type float64).
# # ????????????????????????There are 8 qualitative variables (or Categorical variables)
# # ????????????????????????There are 4 qualitative variables are strings.
#
# - How would you transform these values into numerical values ?
# # ????????????????????????type_of_property initially was qualitative variable where house and apartment are the 2 values in the column. Transformation was done during cleaning data phrase where we have replace house : 0 & apartment :1
#
# Percentage of missing values per column ?
# # ???????????????????????????

# %% [markdown]
# # **Univariate Analysis**
# ### **Price**

# %%
# check the distribution of the price

plt.hist(df['Price'], bins=50);

# %%
sns.distplot(df['Price'], hist=False)
# Out:
# C:\Users\fomic\AppData\Local\Temp\ipykernel_8732\3615690496.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'], hist=False)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# closer look at the distribution by plotting a simple histogram with 10 bins.

plt.figure(figsize=(20,10));  # makes the plot wider
plt.hist(df['Price'], color='r');  # plots a simple histogram
plt.axvline(df['Price'].mean(), color='m', linewidth=3,label='Mean')  # draw a line for mean
plt.axvline(df['Price'].median(), color='b', linestyle='dashed', linewidth=3,label='Medium') # draw a line for median
plt.axvline(df['Price'].mode()[0], color='g', linestyle='dashed', linewidth=3,label='Mode') # draw a line for mode

plt.title('Price for houses & apartment in Belgium')
plt.xlabel('Price')    # label the x-axis
plt.ylabel('Numbers of house or apartment')    # label the y-axis
plt.legend()      # Plot the legend

mean=round(df['Price'].mean())
median=round(df['Price'].median())
mode=round(df['Price'].mode())

print('\t\t\t\t\t\t Mean: ',mean,'  Median: ',median,'  Mode:',mode[0])
# Out:
# 						 Mean:  346379   Median:  315000   Mode: 299000.0

# %% [markdown]
# **Observation:**
#
# In the above histogram we can see that the fourth bin with the price between 300,000 to 350,000 has the most numbers of observation.
# Majority of the observations lie in fourth bin.
# Mean is **346,379**, Median is **315,000** & mode is **299,000** euro.

# %%
# create separate dataframe for house & apartment 

df_house = df[df['Type_of_Property'] == "HOUSE"]

df_apartment = df[df['Type_of_Property'] == "APARTMENT"]

# %%
# plot histrogram for only houses

plt.figure(figsize=(20,10));  # makes the plot wider
plt.hist(df_house['Price'], color='r');  # plots a simple histogram
plt.axvline(df_house['Price'].mean(), color='m', linewidth=3,label='Mean')  # draw a line for mean
plt.axvline(df_house['Price'].median(), color='b', linestyle='dashed', linewidth=3,label='Medium') # draw a line for median
plt.axvline(df_house['Price'].mode()[0], color='g', linestyle='dashed', linewidth=3,label='Mode') # draw a line for mode

plt.title('Price for houses in Belgium')
plt.xlabel('Price')    # label the x-axis
plt.ylabel('Numbers of houses')    # label the y-axis
plt.legend()      # Plot the legend

mean=round(df_house['Price'].mean())
median=round(df_house['Price'].median())
mode=round(df_house['Price'].mode())

print('\t\t\t\t\t\t Mean: ',mean,'  Median: ',median,'  Mode:',mode[0])
# Out:
# 						 Mean:  363644   Median:  345000   Mode: 299000.0

# %% [markdown]
# # ??????????????**Observation:**
#
# In the above histogram we can see that the fourth bin with the price between 300,000 to 400,000 has the most numbers of observation.
# Majority of the observations lie within the second to fifth bin.
# Mean is 363,644, Median is 345,000 & mode is 299,000 euro.

# %%
# plot histrogram for only apartment

plt.figure(figsize=(20,10));  # makes the plot wider
plt.hist(df_apartment['Price'], color='r');  # plots a simple histogram
plt.axvline(df_apartment['Price'].mean(), color='m', linewidth=3,label='Mean')  # draw a line for mean
plt.axvline(df_apartment['Price'].median(), color='b', linestyle='dashed', linewidth=3,label='Medium') # draw a line for median
plt.axvline(df_apartment['Price'].mode()[0], color='g', linestyle='dashed', linewidth=3,label='Mode') # draw a line for mode

plt.title('Price for apartment in Belgium')
plt.xlabel('Price')    # label the x-axis
plt.ylabel('Numbers of apartment')    # label the y-axis
plt.legend()      # Plot the legend

mean=round(df_apartment['Price'].mean())
median=round(df_apartment['Price'].median())
mode=round(df_apartment['Price'].mode())

print('\t\t\t\t\t\t Mean: ',mean,'  Median: ',median,'  Mode:',mode[0])
# Out:
# 						 Mean:  328352   Median:  290000   Mode: 299000.0
