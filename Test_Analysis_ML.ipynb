# %%
import pandas as pd

# %%
# df =pd.read_csv(r"C:\Users\fomic\Python_BootCamp\Python_BootCamp_Fork_Clone\Immo_BackUp\Analysis\cleaned_data.csv") - full link
data = pd.read_csv("cleaned_data.csv") # just mentioned file
data
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 2      154000              Grivegnee        Apartment           APARTMENT
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
data["Type_of_Property"].value_counts()
# Out:
# Type_of_Property
# House        12936
# Apartment    10966
# Name: count, dtype: int64

# %%
# look at the head of data
data.head()
# Out:
#     Price               Locality Type_of_Property Subtype_of_Property  \
# 0  371800           Tielt (8700)            House               HOUSE
# 1  185000                 Ougrée            House               HOUSE
# 2  154000              Grivegnee        Apartment           APARTMENT
# 3  353971           Maasmechelen        Apartment           APARTMENT
# 4  214000  Oupeye Heurele-Romain            House               HOUSE
#
#    Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  Open_fire  \
# 0                3        145.0                       0          0          0
# 1                2        112.0                       0          0          0
# 2                2         85.0                       0          0          0
# 3                3        108.0                       0          0          0
# 4                2        124.0                       0          0          0
#
#    Terrace  Terrace_Area  Garden  Garden_Area  Surface_of_the_Land  \
# ...

# %%
# look at the tail of data
data.tail()
# Out:
#         Price   Locality Type_of_Property Subtype_of_Property  \
# 23897  699000      Uccle            House          TOWN_HOUSE
# 23898  575000  Herentals            House               HOUSE
# 23899  445000      Liège        Apartment           APARTMENT
# 23900  506900  Auderghem        Apartment           APARTMENT
# 23901  235000  Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# 23897                4        190.0                       0          0
# 23898                4        429.0                       0          0
# 23899                3        140.0                       1          0
# 23900                2         88.0                       1          0
# 23901                2         85.0                       0          0
#
#        Open_fire  Terrace  Terrace_Area  Garden  Garden_Area  \
# 23897          0      1.0           3.0     1.0         85.0
# ...

# %%
# look at the first 7 lines of data
data.head(7)
# Out:
#     Price               Locality Type_of_Property Subtype_of_Property  \
# 0  371800           Tielt (8700)            House               HOUSE
# 1  185000                 Ougrée            House               HOUSE
# 2  154000              Grivegnee        Apartment           APARTMENT
# 3  353971           Maasmechelen        Apartment           APARTMENT
# 4  214000  Oupeye Heurele-Romain            House               HOUSE
# 5  599000                 Brugge            House               VILLA
# 6  649000             Gentbrugge        Apartment           APARTMENT
#
#    Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  Open_fire  \
# 0                3        145.0                       0          0          0
# 1                2        112.0                       0          0          0
# 2                2         85.0                       0          0          0
# 3                3        108.0                       0          0          0
# ...

# %%
# look at the last 7 ines of data
data.tail(7)
# Out:
#         Price      Locality Type_of_Property Subtype_of_Property  \
# 23895  369000         Zwalm            House               HOUSE
# 23896  124000  Saint-Hubert            House               HOUSE
# 23897  699000         Uccle            House          TOWN_HOUSE
# 23898  575000     Herentals            House               HOUSE
# 23899  445000         Liège        Apartment           APARTMENT
# 23900  506900     Auderghem        Apartment           APARTMENT
# 23901  235000     Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# 23895                4        195.0                       0          0
# 23896                4         97.0                       0          0
# 23897                4        190.0                       0          0
# 23898                4        429.0                       0          0
# 23899                3        140.0                       1          0
# ...

# %%
# look at general info about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23902 entries, 0 to 23901
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Price                      23902 non-null  int64
#  1   Locality                   23902 non-null  object
#  2   Type_of_Property           23902 non-null  object
#  3   Subtype_of_Property        23902 non-null  object
#  4   Number_of_Rooms            23902 non-null  int64
#  5   Living_Area                22966 non-null  float64
#  6   Fully_Equipped_Kitchen     23902 non-null  int64
#  7   Furnished                  23902 non-null  int64
#  8   Open_fire                  23902 non-null  int64
#  9   Terrace                    16092 non-null  float64
#  10  Terrace_Area               10016 non-null  float64
#  11  Garden                     5565 non-null   float64
#  12  Garden_Area                5565 non-null   float64
# ...

# %%
# look at describing of data (count, mean, std, min, max)
data.describe()
# Out:
#               Price  Number_of_Rooms   Living_Area  Fully_Equipped_Kitchen  \
# count  2.390200e+04     23902.000000  22966.000000            23902.000000
# mean   4.645297e+05         2.875450    168.035008                0.186302
# std    5.141224e+05         1.623282    150.038076                0.389359
# min    5.000000e+03         0.000000     12.000000                0.000000
# 25%    2.400000e+05         2.000000     92.000000                0.000000
# 50%    3.400000e+05         3.000000    135.000000                0.000000
# 75%    4.954432e+05         4.000000    199.000000                0.000000
# max    2.250000e+07        60.000000   7515.000000                1.000000
#
#           Furnished     Open_fire  Terrace  Terrace_Area  Garden  \
# count  23902.000000  23902.000000  16092.0  10016.000000  5565.0
# mean       0.038532      0.085265      1.0     26.378694     1.0
# std        0.192482      6.471587      0.0     74.339565     0.0
# ...

# %%
data.head()
# Out:
#     Price               Locality Type_of_Property Subtype_of_Property  \
# 0  371800           Tielt (8700)            House               HOUSE
# 1  185000                 Ougrée            House               HOUSE
# 2  154000              Grivegnee        Apartment           APARTMENT
# 3  353971           Maasmechelen        Apartment           APARTMENT
# 4  214000  Oupeye Heurele-Romain            House               HOUSE
#
#    Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  Open_fire  \
# 0                3        145.0                       0          0          0
# 1                2        112.0                       0          0          0
# 2                2         85.0                       0          0          0
# 3                3        108.0                       0          0          0
# 4                2        124.0                       0          0          0
#
#    Terrace  Terrace_Area  Garden  Garden_Area  Surface_of_the_Land  \
# ...

# %%
# check empty raws
data.isna()
# Out:
#        Price  Locality  Type_of_Property  Subtype_of_Property  \
# 0      False     False             False                False
# 1      False     False             False                False
# 2      False     False             False                False
# 3      False     False             False                False
# 4      False     False             False                False
# ...      ...       ...               ...                  ...
# 23897  False     False             False                False
# 23898  False     False             False                False
# 23899  False     False             False                False
# 23900  False     False             False                False
# 23901  False     False             False                False
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# 0                False        False                   False      False
# 1                False        False                   False      False
# ...

# %%
data
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 2      154000              Grivegnee        Apartment           APARTMENT
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
# calculate empty raws
data.isna().sum()
# Out:
# Price                            0
# Locality                         0
# Type_of_Property                 0
# Subtype_of_Property              0
# Number_of_Rooms                  0
# Living_Area                    936
# Fully_Equipped_Kitchen           0
# Furnished                        0
# Open_fire                        0
# Terrace                       7810
# Terrace_Area                 13886
# Garden                       18337
# Garden_Area                  18337
# Surface_of_the_Land          18337
# Surface_area_plot_of_land    10966
# Number_of_Facades             7020
# Swimming_Pool                    0
# State_of_the_Building         3731
# dtype: int64

# %%
# to delete columns
df = data.drop(columns = ["Open_fire", "Terrace", "Terrace_Area", "Garden", "Garden", "Surface_of_the_Land", "Surface_area_plot_of_land", "Garden_Area", "Number_of_Facades"])
# df = data.drop(columns = ["Open_fire"], ["Number_of_Fasades"]) # to name dataset for our analysis
# data.drop(columns = ["Open_fire"], ["Number_of_Fasades"], inplace = True) - to inplace our dataset

# %%
df
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 2      154000              Grivegnee        Apartment           APARTMENT
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
# to count values by the columns
df["Type_of_Property"].value_counts()
# Out:
# Type_of_Property
# House        12936
# Apartment    10966
# Name: count, dtype: int64

# %%
# check duplicates
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23897    False
# 23898    False
# 23899    False
# 23900    False
# 23901    False
# Length: 23902, dtype: bool

# %%
df
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 2      154000              Grivegnee        Apartment           APARTMENT
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
# calculate duplicates
df.duplicated().sum()
# Out:
# 1066

# %%
df
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 2      154000              Grivegnee        Apartment           APARTMENT
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
# to delete duplicates
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 2      154000              Grivegnee        Apartment           APARTMENT
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
# count duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 2      154000              Grivegnee        Apartment           APARTMENT
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
df.shape
# Out:
# (22836, 10)

# %%
# to count total amount of any values
df.isna().sum().sum()
# Out:
# 4457

# %%
df
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 2      154000              Grivegnee        Apartment           APARTMENT
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# 5      599000                 Brugge            House               VILLA
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# 5      599000                 Brugge            House               VILLA
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
df.head(7)
# Out:
#      Price               Locality Type_of_Property Subtype_of_Property  \
# 0   371800           Tielt (8700)            House               HOUSE
# 1   185000                 Ougrée            House               HOUSE
# 3   353971           Maasmechelen        Apartment           APARTMENT
# 4   214000  Oupeye Heurele-Romain            House               HOUSE
# 5   599000                 Brugge            House               VILLA
# 6   649000             Gentbrugge        Apartment           APARTMENT
# 7  3700000           Knokke-Heist            House               HOUSE
#
#    Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# 0                3        145.0                       0          0
# 1                2        112.0                       0          0
# 3                3        108.0                       0          0
# 4                2        124.0                       0          0
# ...

# %%
# to count values by the columns
df["Subtype_of_Property"].value_counts()
# Out:
# Subtype_of_Property
# HOUSE                   7595
# APARTMENT               6541
# VILLA                    942
# DUPLEX                   460
# GROUND_FLOOR             433
# MIXED_USE_BUILDING       430
# APARTMENT_BLOCK          429
# PENTHOUSE                381
# FLAT_STUDIO              316
# EXCEPTIONAL_PROPERTY     184
# MANSION                  179
# TOWN_HOUSE               123
# BUNGALOW                 110
# SERVICE_FLAT             102
# COUNTRY_COTTAGE           99
# LOFT                      85
# TRIPLEX                   58
# KOT                       42
# FARMHOUSE                 39
# CHALET                    20
# CASTLE                    10
# MANOR_HOUSE                9
# OTHER_PROPERTY             6
# PAVILION                   1
# Name: count, dtype: int64

# %%
# to COUNT and CORT values (ascending)
df["Subtype_of_Property"].value_counts().sort_values(ascending = True)
# Out:
# Subtype_of_Property
# PAVILION                   1
# OTHER_PROPERTY             6
# MANOR_HOUSE                9
# CASTLE                    10
# CHALET                    20
# FARMHOUSE                 39
# KOT                       42
# TRIPLEX                   58
# LOFT                      85
# COUNTRY_COTTAGE           99
# SERVICE_FLAT             102
# BUNGALOW                 110
# TOWN_HOUSE               123
# MANSION                  179
# EXCEPTIONAL_PROPERTY     184
# FLAT_STUDIO              316
# PENTHOUSE                381
# APARTMENT_BLOCK          429
# MIXED_USE_BUILDING       430
# GROUND_FLOOR             433
# DUPLEX                   460
# VILLA                    942
# APARTMENT               6541
# HOUSE                   7595
# Name: count, dtype: int64

# %%
# to COUNT and CORT values (discending) and look at TOP 7
df["Subtype_of_Property"].value_counts().sort_values(ascending = False).head(7)
# Out:
# Subtype_of_Property
# HOUSE                 7595
# APARTMENT             6541
# VILLA                  942
# DUPLEX                 460
# GROUND_FLOOR           433
# MIXED_USE_BUILDING     430
# APARTMENT_BLOCK        429
# Name: count, dtype: int64

# %%
# to COUNT and CORT values (discending) and look at plot var
df["Type_of_Property"].value_counts().sort_values(ascending = False).head(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='Type_of_Property'>

# %%
import matplotlib.pyplot as plt

# %%
# use matplotlib.pyplot to apdate our bar
df["Subtype_of_Property"].value_counts().sort_values(ascending = False).head(10).plot(kind = "bar")
plt.title("Number of Subtype of Property")
plt.ylabel("Listing Number")
plt.xlabel("Types")
plt.show()

# %%
df
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# 5      599000                 Brugge            House               VILLA
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
df.groupby(["Locality", "Type_of_Property"])["Price"].mean()
# Out:
# Locality          Type_of_Property
# 'S Gravenwezel    House               590000.0
# 'S-Gravenwezel    House               549000.0
# Aaigem            House               495000.0
# Aalbeke           Apartment           249000.0
#                   House               428180.0
#                                         ...
# Écaussinnes       Apartment           215000.0
#                   House               289137.5
# Érezée            House               278300.0
# Étalle            House               457500.0
# Étalle (Buzenol)  House               295000.0
# Name: Price, Length: 2480, dtype: float64

# %%
df.groupby(["Locality", "Type_of_Property"])["Price"].mean().reset_index()
# Out:
#               Locality Type_of_Property     Price
# 0       'S Gravenwezel            House  590000.0
# 1       'S-Gravenwezel            House  549000.0
# 2               Aaigem            House  495000.0
# 3              Aalbeke        Apartment  249000.0
# 4              Aalbeke            House  428180.0
# ...                ...              ...       ...
# 2475       Écaussinnes        Apartment  215000.0
# 2476       Écaussinnes            House  289137.5
# 2477            Érezée            House  278300.0
# 2478            Étalle            House  457500.0
# 2479  Étalle (Buzenol)            House  295000.0
#
# [2480 rows x 3 columns]

# %%
# to find correlation between valeus and Price
df.select_dtypes(include=["number"])
# Out:
#         Price  Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  \
# 0      371800                3        145.0                       0
# 1      185000                2        112.0                       0
# 3      353971                3        108.0                       0
# 4      214000                2        124.0                       0
# 5      599000                4        288.0                       0
# ...       ...              ...          ...                     ...
# 23897  699000                4        190.0                       0
# 23898  575000                4        429.0                       0
# 23899  445000                3        140.0                       1
# 23900  506900                2         88.0                       1
# 23901  235000                2         85.0                       0
#
#        Furnished  Swimming_Pool
# 0              0              0
# 1              0              0
# 3              0              0
# ...

# %%
# full line to find correlation between valeus and Price
df.select_dtypes(include=["number"]).corr()["Price"]
# Out:
# Price                     1.000000
# Number_of_Rooms           0.358212
# Living_Area               0.443005
# Fully_Equipped_Kitchen    0.227380
# Furnished                 0.038816
# Swimming_Pool             0.274705
# Name: Price, dtype: float64

# %%
df
# Out:
#         Price               Locality Type_of_Property Subtype_of_Property  \
# 0      371800           Tielt (8700)            House               HOUSE
# 1      185000                 Ougrée            House               HOUSE
# 3      353971           Maasmechelen        Apartment           APARTMENT
# 4      214000  Oupeye Heurele-Romain            House               HOUSE
# 5      599000                 Brugge            House               VILLA
# ...       ...                    ...              ...                 ...
# 23897  699000                  Uccle            House          TOWN_HOUSE
# 23898  575000              Herentals            House               HOUSE
# 23899  445000                  Liège        Apartment           APARTMENT
# 23900  506900              Auderghem        Apartment           APARTMENT
# 23901  235000              Ganshoren        Apartment           APARTMENT
#
#        Number_of_Rooms  Living_Area  Fully_Equipped_Kitchen  Furnished  \
# ...

# %%
X = df[["Number_of_Rooms", "Living_Area"]]

# %%
y = df["Price"]

# %%
X
# Out:
#        Number_of_Rooms  Living_Area
# 0                    3        145.0
# 1                    2        112.0
# 3                    3        108.0
# 4                    2        124.0
# 5                    4        288.0
# ...                ...          ...
# 23897                4        190.0
# 23898                4        429.0
# 23899                3        140.0
# 23900                2         88.0
# 23901                2         85.0
#
# [18594 rows x 2 columns]

# %%
y
# Out:
# 0        371800
# 1        185000
# 3        353971
# 4        214000
# 5        599000
#           ...
# 23897    699000
# 23898    575000
# 23899    445000
# 23900    506900
# 23901    235000
# Name: Price, Length: 18594, dtype: int64

# %%
X.columns
# Out:
# Index(['Number_of_Rooms', 'Living_Area'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.59773482, -0.39873938],
#        [ 0.05566208, -0.1947333 ],
#        [ 0.70905898,  1.06220739],
#        ...,
#        [-0.59773482, -0.62248799],
#        [ 0.05566208,  1.29253684],
#        [ 1.36245588, -0.12892489]])

# %%
import joblib
joblib.dump(scaler, "Scaler.pkl")
# Out:
# ['Scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([845059.79180122, 659668.16190019, 262407.56031399, ...,
#        353376.22806544, 638942.39551156, 385621.89104909])

# %%
predictions = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 211953.79488017855

# %%
data["Price"].describe().astype(int)
# Out:
# count       23902
# mean       464529
# std        514122
# min          5000
# 25%        240000
# 50%        340000
# 75%        495443
# max      22500000
# Name: Price, dtype: int32

# %%
joblib.dump(lr, "model.pkl")
# Out:
# ['model.pkl']
